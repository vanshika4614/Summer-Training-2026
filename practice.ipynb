# %%
random_arr = np.random.randint(10,50,size=(5,5))

random_arr[random_arr>30]=30
random_arr
# Out:
# array([[30, 15, 30, 14, 23],
#        [28, 13, 28, 30, 30],
#        [30, 30, 30, 30, 30],
#        [20, 23, 22, 14, 30],
#        [30, 23, 25, 30, 30]], dtype=int32)

# %%
arr = np.arange(6)
arr.reshape(3, 2)
# arr.reshape(4, 3)
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
h3=np.linspace(0,1,100)
np.sin(h3)
# Out:
# array([0.        , 0.01010084, 0.02020065, 0.03029839, 0.04039305,
#        0.05048358, 0.06056897, 0.07064817, 0.08072016, 0.09078392,
#        0.10083842, 0.11088263, 0.12091552, 0.13093608, 0.14094328,
#        0.1509361 , 0.16091352, 0.17087452, 0.18081808, 0.1907432 ,
#        0.20064886, 0.21053404, 0.22039774, 0.23023896, 0.24005668,
#        0.24984992, 0.25961766, 0.26935891, 0.27907268, 0.28875797,
#        0.2984138 , 0.30803919, 0.31763315, 0.3271947 , 0.33672286,
#        0.34621667, 0.35567516, 0.36509735, 0.3744823 , 0.38382904,
#        0.39313661, 0.40240408, 0.41163048, 0.42081489, 0.42995636,
#        0.43905397, 0.44810678, 0.45711386, 0.46607431, 0.47498721,
#        0.48385164, 0.49266671, 0.5014315 , 0.51014514, 0.51880673,
#        0.52741539, 0.53597023, 0.54447039, 0.55291499, 0.56130318,
#        0.56963411, 0.57790691, 0.58612075, 0.59427479, 0.60236819,
#        0.61040014, 0.6183698 , 0.62627638, 0.63411905, 0.64189703,
# ...

# %%
h1 = np.array([
    [10, 20, 30],
    [60, 70, 80],
    [40, 50, 60],
    [90, 95, 100]
])
row_means = np.mean(h1, axis=1)
result = h1[row_means > 50]
print("\nRows where mean > 50:")
print(result)
# Out:
# Rows where mean > 50:
# [[ 60  70  80]
#  [ 90  95 100]]

# %%
import numpy as np

# Create two NumPy arrays
arr1 = np.array([10, 20, 30, 40, 50])
arr2 = np.array([2, 5, 0, 8, 10])

addition = arr1 + arr2
subtraction = arr1 - arr2
multiplication = arr1 * arr2
print("Array 1:", arr1)
print("Array 2:", arr2)
print(addition)
print(subtraction)
print(multiplication)
# Out:
# Array 1: [10 20 30 40 50]
# Array 2: [ 2  5  0  8 10]
# [12 25 30 48 60]
# [ 8 15 30 32 40]
# [ 20 100   0 320 500]

# %%
df=pd.read_csv('company_sales_data.csv')
df.head(10)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
# 5             6       2760      1555        4890         7490     1890
# 6             7       2980      1120        4780         8980     1780
# 7             8       3700      1400        5860         9960     2860
# 8             9       3540      1780        6100         8100     2100
# 9            10       1990      1890        8300        10300     2300
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# ...

# %%
df.describe()
# Out:
#        month_number    facecream     facewash   toothpaste   bathingsoap  \
# count     12.000000    12.000000    12.000000    12.000000     12.000000
# mean       6.500000  2873.333333  1542.916667  5825.833333   9500.833333
# std        3.605551   584.595172   316.733745  1242.032486   2348.095779
# min        1.000000  1990.000000  1120.000000  4550.000000   6100.000000
# 25%        3.750000  2460.000000  1305.000000  4862.500000   8015.000000
# 50%        6.500000  2830.000000  1527.500000  5530.000000   9090.000000
# 75%        9.250000  3435.000000  1765.000000  6400.000000  10045.000000
# max       12.000000  3700.000000  2100.000000  8300.000000  14400.000000
#
#            shampoo  moisturizer  total_units   total_profit
# count    12.000000    12.000000     12.00000      12.000000
# mean   2117.500000  1542.916667  26027.50000  260275.000000
# std     617.724931   316.733745   7014.36594   70143.659404
# min    1200.000000  1120.000000  18330.00000  183300.000000
# ...

# %%
arr = np.random.randint(low=1, high=100, size=(5, 5))
arr
df = pd.DataFrame(arr, index=["Aman", "Bhanu", "Chintu", "Dreak", "Elephant"], columns=["maths", "science", "evs", "avarage", "Total"])
df["total"]=df.sum(axis=1)
df["average"]=df.mean(axis=1)
df
# Out:
#           maths  science  evs  avarage  Total  total    average
# Aman         44       40   30       39     23    176  58.666667
# Bhanu        18       91   30       23     31    193  64.333333
# Chintu       85       43   18       13      9    168  56.000000
# Dreak        28       25   83       67     82    285  95.000000
# Elephant      7        2   23        2     74    108  36.000000

# %%
colmn=df.describe().columns
mean=df[colmn].mean()
df[df[colmn]>mean]
# Out:
#           maths  science   evs  avarage  Total  total    average
# Aman       44.0      NaN   NaN     39.0    NaN    NaN        NaN
# Bhanu       NaN     91.0   NaN      NaN    NaN  193.0  64.333333
# Chintu     85.0     43.0   NaN      NaN    NaN    NaN        NaN
# Dreak       NaN      NaN  83.0     67.0   82.0  285.0  95.000000
# Elephant    NaN      NaN   NaN      NaN   74.0    NaN        NaN

# %%
df=pd.read_csv('company_sales_data.csv')
grouped_df= df.groupby('month_number')
grouped_df.mean()
# Out:
#               facecream  facewash  toothpaste  bathingsoap  shampoo  \
# month_number
# 1                2500.0    1500.0      5200.0       9200.0   1200.0
# 2                2630.0    1200.0      5100.0       6100.0   2100.0
# 3                2140.0    1340.0      4550.0       9550.0   3550.0
# 4                3400.0    1130.0      5870.0       8870.0   1870.0
# 5                3600.0    1740.0      4560.0       7760.0   1560.0
# 6                2760.0    1555.0      4890.0       7490.0   1890.0
# 7                2980.0    1120.0      4780.0       8980.0   1780.0
# 8                3700.0    1400.0      5860.0       9960.0   2860.0
# 9                3540.0    1780.0      6100.0       8100.0   2100.0
# 10               1990.0    1890.0      8300.0      10300.0   2300.0
# 11               2340.0    2100.0      7300.0      13300.0   2400.0
# 12               2900.0    1760.0      7400.0      14400.0   1800.0
#
#               moisturizer  total_units  total_profit
# month_number
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.plot(x['total_profit'])
plt.title("Total profit of all months")
plt.xlabel("Month Number")
plt.ylabel("Total Profit")

x=pd.read_csv('D:/STUDY_HUB/PROJECTS/Summer-Training-2026/company_sales_data.csv')
plt.show()

# %%
data = {
    "Name": ["Aman", "Riya", "Naman", "Priya"],
    "Marks": [80, 75, 90, 85]
}

df = pd.DataFrame(data)

# Sort by Name (ascending) and Marks (descending)
sorted_df = df.sort_values(by=["Name", "Marks"], ascending=[True, False])

print(sorted_df)
# Out:
#     Name  Marks
# 0   Aman     80
# 2  Naman     90
# 3  Priya     85
# 1   Riya     75

# %%
import pandas as pd

df1 = pd.DataFrame({"ID": [1, 2, 3], "Name": ["Aman", "Riya", "Raj"]})

df2 = pd.DataFrame({"ID": [2, 3, 4],"Marks": [85, 90, 75]})

result = pd.merge(df1, df2, on="ID", how="inner")

print(result)
# Out:
#    ID  Name  Marks
# 0   2  Riya     85
# 1   3   Raj     90

# %%
days = [1, 2, 3, 4, 5]
sales = [100, 120, 150, 130, 170]

plt.plot(days, sales)

plt.show()

# %%
df = pd.DataFrame({
    "Category": ["Books", "Pens", "Bags"],
    "Total": [15, 25, 10]
})

plt.bar(df["Category"], df["Total"])

plt.show()

# %%
months = ["Jan", "Feb", "Mar", "Apr"]
sales = [100, 120, 150, 130]

plt.plot(months, sales, label="Sales")
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.grid(True)
plt.legend()

plt.show()
